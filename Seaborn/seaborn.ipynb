# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **HISTOGRAM**
# A histogram is a type of bar plot that represents the distribution of a numerical dataset. It shows the frequency of data points within specified ranges (bins). Histograms are widely used in exploratory data analysis (EDA) to understand the shape, spread, and central tendency of data.
# Where Histograms Are Used
#
# 1.Data Analysis: Helps identify data distribution (normal, skewed, etc.).
# 2.Statistics: Shows frequency distributions, enabling better decision-making.
# 3.Machine Learning: Used for feature engineering and outlier detection.

# %%
SocialMedia = pd.DataFrame({ 
    'User': ['User1', 'User2', 'User3', 'User4', 'User5', 'User6', 'User7', 'User8', 'User9', 'User10', 'User11', 'User12', 'User13', 'User14', 'User15'], 
    'Platform': ['Facebook', 'Twitter', 'Instagram', 'LinkedIn', 'Snapchat', 'Facebook', 'Twitter', 'Instagram', 'LinkedIn', 'Snapchat', 'Facebook', 'Twitter', 'Instagram', 'LinkedIn', 'Snapchat'], 
    'Followers': [150, 200, 200, 366, 350, 456, 450, 785, 550, 600, 750, 700, 750, 800, 850], 
    'Posts': [10, 20, 15, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]})

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=SocialMedia, x='Followers', bins= 5, kde=True, color='blue')
# kde = Kernel Density Estimation
# 
plt.title('Distribution of Followers', fontsize=14)
plt.xlabel('Number of Followers', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

plt.show()

print(SocialMedia['Followers'].skew())
# Out:
# -0.2598121572745581

# %% [markdown]
# ## **KDE (Kernel Density Estimation) Plot**
# A KDE plot is a smoothed version of a histogram that estimates the probability density function of the data. It provides a continuous, smooth curve representing the data distribution.
#
# • Key Features of KDE in the Plot:
# • Histogram with KDE: The bars represent the frequency of values, and the KDE curve overlays the histogram.
# • Smooth Distribution Curve: The KDE curve helps identify peaks, trends, and outliers more effectively than a histogram.
# • Helps in Data Understanding:
#         – If the KDE plot is unimodal, the data has a single peak.
#         – If the KDE plot is multimodal, it indicates multiple clusters in the data.
# • Where is KDE Used?
# • Social Media Analytics: Understanding user engagement trends (e.g., how many users fall within a certain range of followers).
# • Finance: Analyzing stock price distributions over time.
# • Marketing: Examining customer purchase behavior patterns.
# • Machine Learning: Checking if data follows a normal distribution before applying models.

# %%
#Plotting the KDE
sns.kdeplot(SocialMedia["Followers"],
           shade=True,
           color="red")
plt.title("KDE Graph of Followers")
plt.show()
print(f"Skew value: {SocialMedia["Followers"].skew()}")
#positive skewness -right skewed -means the tail is on the right side of the distribution
#negative skewness -left skewed-means the tail is on the left side of the distribution
# Out:
# C:\Users\MOHIT\AppData\Local\Temp\ipykernel_25424\2443845068.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(SocialMedia["Followers"],
# Skew value: -0.2598121572745581

# %%
sales=pd.DataFrame({"Day":["Mon","Tues","Wed","Thur","Fri","Mon","Tues","Wed","Thur","Fri"],
    "Product":['A','A','A','B','B','B','C','C','C','C'],
    "Sales":[120,150,90,200,180,220,80,95,110,130],
    "Customer_Rating":[4.2,4.5,3.8,4.7,4.3,4.6,3.9,4.1,4.4,4.0],
    "Discount":[5,10,15,0,20,10,0,5,10,15]
})

sns.catplot(data=sales,x="Day",y="Sales",kind="bar",hue="Product")
plt.title("Sales per Day")
plt.xlabel("Day")
plt.ylabel("Sales")
plt.show()

# %%
sales=pd.DataFrame({"Day":["Mon","Tues","Wed","Thur","Fri","Mon","Tues","Wed","Thur","Fri"],
    "Product":['A','A','A','B','B','B','C','C','C','C'],
    "Sales":[120,150,90,200,180,220,800,95,110,130],
    "Customer_Rating":[4.2,4.5,3.8,4.7,4.3,4.6,3.9,4.1,7.8,4.0],
    "Discount":[5,10,15,0,20,10,0,50,10,15]
})

sns.catplot(data=sales,x="Day",y="Sales",kind="bar",hue="Product")
plt.title("Sales per Day")
plt.xlabel("Day")
plt.ylabel("Sales")
plt.show()

# %%
for i in sales.select_dtypes(include=["number"]).columns:
    sns.boxplot(data=sales,y=i,color="#ffcce6",
                showmeans=True,
                meanline=True,
                showcaps=True,
                showbox=True,
                showfliers=True,
                linewidth=1,
                linecolor="black")
    mean_value=sales[i].mean()
    median_value=sales[i].median()
    q1=sales[i].quantile(0.25)
    q3=sales[i].quantile(0.75)
    IQR=q3-q1
    plt.text(0,mean_value,
            f"Mean:{mean_value:.2f}",# 0 and 1 means the x and y axis values,
             ha='left',
             va='bottom',fontsize=8,color='Green')
    plt.text(0,median_value,
            f"Median:{median_value:.2f}",
             ha='right',
             va='top',fontsize=8,color='black')
    plt.text(0,q1,
            f"Quartile 0.25---:{q1:.2f}",
             ha="center",
             va='top',fontsize=8,color='blue')
    plt.text(0,q3,
            f"Quatile 0.75----:{q3:.2f}",
            ha='center',
            va='top',fontsize=8,color='blue')
    plt.text(0,q1-1.5*IQR,
            f"Lower Whisker:{q1-1.5*IQR:.2f}",
            ha='center',
            va='top',fontsize=8,color='black')
    plt.text(0,q1-1.5*IQR,
            f"Upper Whisker:{q3+1.5*IQR:.2f}",
            ha='center',
            va='top',fontsize=8,color='black')
    plt.title(f"Boxplot of{i}")
    plt.show()

# %% [markdown]
# ## **ScatterPlot Matrix (Pair Plot)**

# %%
sns.pairplot(SocialMedia)
plt.show()

# %%
# Compute the correlation matrix
corr_matrix = SocialMedia[['Followers','Posts']].corr()

# Plotting the heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes
G.add_nodes_from(['Alice', 'Bob', 'Charlie', 'David', 'Eve'])

# Add directed edges (relationships)
G.add_edges_from([
    ('Alice', 'Bob'), 
    ('Alice', 'Charlie'), 
    ('Bob', 'David'), 
    ('Charlie', 'Eve'), 
    ('David', 'Eve')])

# Draw the graph with arrows
plt.figure(figsize=(8, 5))
pos = nx.spring_layout(G) # Position nodes using spring layout
nx.draw_networkx(G, pos, with_labels=True, node_color='skyblue', node_size=2000, 
         font_size=10, font_weight='bold',edge_color='grey', arrows=True, arrowsize=20)

plt.title('Social Network with Directed Edges')
plt.show()

# %%
F = nx.DiGraph()

F.add_nodes_from(['Alice', 'Bob', 'Charlie', 'David', 'Eve'])

F.add_edges_from([
    ('Alice', 'Bob'), 
    ('Alice', 'Charlie'), 
    ('Bob', 'David'), 
    ('Chalie', 'Eve'), 
    ('David', 'Eve'),
    ('Alice', 'Bob'), 
    ('Alic', 'Charlie'), 
    ('Bob', 'Davi'), 
    ('Charlie', 'Ev'), 
    ('Davi', 'Eve')])

plt.figure(figsize=(14, 8))
pos = nx.spring_layout(F) 
nx.draw_networkx(F, pos, with_labels=True, node_color='orange', node_size=2000, 
                 font_size=10, font_weight='bold', edge_color='black', arrows=True, arrowsize=20)

plt.title('Social Network with Directed Edges')
plt.show()

# %%
G = nx.DiGraph()
Users = ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank', 'Grace']

G.add_nodes_from(Users)

edges = [
    ('Alice', 'Bob'), 
    ('Alice', 'Charlie'), 
    ('Bob', 'Diana'), 
    ('Charlie', 'Eve'), 
    ('Diana', 'Frank'), 
    ('Eve', 'Grace'),
    ('Frank', 'Alice'),
    ('Grace', 'Bob')
]

G.add_edges_from(edges)

# Computer number of followers (in-degree)
in_degree = dict(G.in_degree())
node_sizes = [in_degree[node] * 100 for node in G.nodes()] # Scale the node sizes for better visualization

plt.figure(figsize=(10, 6))
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_color='lightgreen', node_size=1500, 
                 font_size=10, font_weight='bold', edge_color='grey', arrows=True, arrowsize=20)

plt.title('Social Network with Node Sizes Based on In-Degree')
plt.show()
