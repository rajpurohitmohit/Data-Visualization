# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
data = pd.read_csv('india_places.csv')

# %%
data
# Out:
#                           State       District        City Population  \
# 0                Andhra Pradesh              -           -   49386799
# 1             Arunachal Pradesh              -           -    1383727
# 2                         Assam              -           -   31169272
# 3                         Bihar              -           -  104099452
# 4                  Chhattisgarh              -           -   25545198
# ...                         ...            ...         ...        ...
# 1292                 Tamil Nadu     Coimbatore     Kurichi     123667
# 1293                 Tamil Nadu       Tiruppur    Tiruppur     444352
# 1294                 Puducherry     Puducherry  Puducherry     244377
# 1295                 Puducherry     Puducherry   Ozhukarai     300104
# 1296  Andaman & Nicobar Islands  South Andaman  Port Blair     108058
#
#      Area (in km^2)  Latitude  Longitude
# 0            160205     16.50      80.63
# 1             83743     27.07      93.37
# 2             78550     26.13      91.77
# 3             94613     25.40      85.10
# 4            135194     21.25      81.60
# ...             ...       ...        ...
# 1292              0     10.97      77.02
# 1293            372     11.11      77.35
# 1294            483     11.90      79.80
# 1295              0     11.95      79.77
# 1296            548     11.62      92.73
#
# [1297 rows x 7 columns]

# %%
m = folium.Map(location=[data['Latitude'].mean(), data['Longitude'].mean()],
           zoom_start=8,
           zoom_control=True,)


for index, row in data.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']],
              popup=row['State'],
              tooltip= 'Click for more',
              icon= folium.Icon(color='red', icon='info-sign')).add_to(m)
    
m.save('new_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa92c37fbb4798f1e97d4f538af244a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa92c37fbb4798f1e97d4f538af244a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa92c37fbb4798f1e97d4f538af244a8 = L.map(
#                 &quot;map_aa92c37fbb4798f1e97d4f538af244a8&quot;,
#                 {
#                     center: [20.937131842713956, 73.71371626831149],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0ba4e57711eac20a5812542c7977340 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0ba4e57711eac20a5812542c7977340.addTo(map_aa92c37fbb4798f1e97d4f538af244a8);
#
#
#             var marker_833a1bbff9bdebd6c0968d74c125ddea = L.marker(
#                 [16.5, 80.63],
#                 {
# }
#             ).addTo(map_aa92c37fbb4798f1e97d4f538af244a8);
#
#
#             var icon_ff783576e0d27bff0b708f0bf2d2b0f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b2fadd26ad6618c1712335d90a51a7f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01d189b8ae7225ce542db8566cbddcdf = $(`&lt;div id=&quot;html_01d189b8ae7225ce542db8566cbddcdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Andhra Pradesh&lt;/div&gt;`)[0];
#                 popup_b2fadd26ad6618c1712335d90a51a7f4.setContent(html_01d189b8ae7225ce542db8566cbddcdf);
#
#
#
#         marker_833a1bbff9bdebd6c0968d74c125ddea.bindPopup(popup_b2fadd26ad6618c1712335d90a51a7f4)
#         ;
#
#
#
#
#             marker_833a1bbff9bdebd6c0968d74c125ddea.bindTooltip(
#                 `&lt;div&gt;
#                      Click for more
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_833a1bbff9bdebd6c0968d74c125ddea.setIcon(icon_ff783576e0d27bff0b708f0bf2d2b0f5);
#
#
#             var marker_514be27815df091cfacb79154f0a88b2 = L.marker(
#                 [27.07, 93.37],
#                 {
# }
#             ).addTo(map_aa92c37fbb4798f1e97d4f538af244a8);
#
#
#             var icon_5f66544864d7c3c1493e712b660b0d7c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_be56f61e683f92b3c650023817d2b8f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ddf3d4251d98ac9d5fec7d0b3d6f73b = $(`&lt;div id=&quot;html_4ddf3d4251d98ac9d5fec7d0b3d6f73b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arunachal Pradesh&lt;/div&gt;`)[0];
#                 popup_be56f61e683f92b3c650023817d2b8f0.setContent(html_4ddf3d4251d98ac9d5fec7d0b3d6f73b);
#
#
#
#         marker_514be27815df091cfacb79154f0a88b2.bindPopup(popup_be56f61e683f92b3c650023817d2b8f0)
#         ;
#
#
#
#
#             marker_514be27815df091cfacb79154f0a88b2.bindTooltip(
#                 `&lt;div&gt;
#                      Click for more
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_514be27815df091cfacb79154f0a88b2.setIcon(icon_5f66544864d7c3c1493e712b660b0d7c);
#
#
#             var marker_ef25055f768e4bfac2777a9292d457e6 = L.marker(
#                 [26.13, 91.77],
#                 {
# }
#             ).addTo(map_aa92c37fbb4798f1e97d4f538af244a8);
#
#
#             var icon_a82f192493bdd3ae9c2a3bcef54d22df = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c284c60bf7f3eac0fd5bc1515b80af20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0318ea1df257140b58c2b9254a3f4c24 = $(`&lt;div id=&quot;html_0318ea1df257140b58c2b9254a3f4c24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Assam&lt;/div&gt;`)[0];
#                 popup_c284c60bf7f3eac0fd5bc1515b80af20.setContent(html_0318ea1df257140b58c2b9254a3f4c24);
#
#
#
#         marker_ef25055f768e4bfac2777a9292d457e6.bindPopup(popup_c2
