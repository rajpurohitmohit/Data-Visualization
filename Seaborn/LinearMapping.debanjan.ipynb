# %%
import pandas as pd
import numpy as np
import folium as fl

# %%
data = pd.DataFrame({
    'city': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
    'lat': [40.7128, 34.0522, 41.8781, 29.7684, 33.4484],
    'lon': [-74.0060, -118.2437, -87.6298, -95.3698, -112.0740]
})

# %%
m = fl.Map(location=(45.5236,-122.6750),
               zoom_start=8,
               zoom_control=True)

# %%
for index, row in data.iterrows():
    fl.Marker([row['lat'], row['lon']],
             popup=row['city'],
             tooltip="click me",
             icon=fl.Icon(color="red")).add_to(m)
m.save("map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d799f1c7346a47f1c76148655628592 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d799f1c7346a47f1c76148655628592&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d799f1c7346a47f1c76148655628592 = L.map(
#                 &quot;map_3d799f1c7346a47f1c76148655628592&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b915be803dc71c1e6946b4b967dcfc75 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b915be803dc71c1e6946b4b967dcfc75.addTo(map_3d799f1c7346a47f1c76148655628592);
#
#
#             var marker_7c7c612213030a5ab52ddd58561f0b64 = L.marker(
#                 [40.7128, -74.006],
#                 {
# }
#             ).addTo(map_3d799f1c7346a47f1c76148655628592);
#
#
#             var icon_49db5075b9563442f36478307f1a4a19 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fae7887667d3537fbc35cfa2f14fcd2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18fea8f119f386cb120eefeb564bb813 = $(`&lt;div id=&quot;html_18fea8f119f386cb120eefeb564bb813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York&lt;/div&gt;`)[0];
#                 popup_fae7887667d3537fbc35cfa2f14fcd2f.setContent(html_18fea8f119f386cb120eefeb564bb813);
#
#
#
#         marker_7c7c612213030a5ab52ddd58561f0b64.bindPopup(popup_fae7887667d3537fbc35cfa2f14fcd2f)
#         ;
#
#
#
#
#             marker_7c7c612213030a5ab52ddd58561f0b64.bindTooltip(
#                 `&lt;div&gt;
#                      click me
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_7c7c612213030a5ab52ddd58561f0b64.setIcon(icon_49db5075b9563442f36478307f1a4a19);
#
#
#             var marker_da0414c3ceb63a864a437a343880ef06 = L.marker(
#                 [34.0522, -118.2437],
#                 {
# }
#             ).addTo(map_3d799f1c7346a47f1c76148655628592);
#
#
#             var icon_b26b1f8614115b3c12ccc276d98e4719 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_813877f6d3d05974b059e460df3bbd5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57f52e6a632057c93caa9b68e202fcde = $(`&lt;div id=&quot;html_57f52e6a632057c93caa9b68e202fcde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_813877f6d3d05974b059e460df3bbd5a.setContent(html_57f52e6a632057c93caa9b68e202fcde);
#
#
#
#         marker_da0414c3ceb63a864a437a343880ef06.bindPopup(popup_813877f6d3d05974b059e460df3bbd5a)
#         ;
#
#
#
#
#             marker_da0414c3ceb63a864a437a343880ef06.bindTooltip(
#                 `&lt;div&gt;
#                      click me
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_da0414c3ceb63a864a437a343880ef06.setIcon(icon_b26b1f8614115b3c12ccc276d98e4719);
#
#
#             var marker_eadad0b65dbe2214dcbcaa4fd7985902 = L.marker(
#                 [41.8781, -87.6298],
#                 {
# }
#             ).addTo(map_3d799f1c7346a47f1c76148655628592);
#
#
#             var icon_f1d548266558caf0dbb0d72ba506f50b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0220b4bc9af3a0de84442704e0de92f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaf5826f71a4ce1971520257222d2d0d = $(`&lt;div id=&quot;html_aaf5826f71a4ce1971520257222d2d0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago&lt;/div&gt;`)[0];
#                 popup_0220b4bc9af3a0de84442704e0de92f0.setContent(html_aaf5826f71a4ce1971520257222d2d0d);
#
#
#
#         marker_eadad0b65dbe2214dcbcaa4fd7985902.bindPopup(popup_0220b4bc9af3a0de84442704e0de

# %%
indian_sales = pd.DataFrame({
    "State Name":['Delhi','Mumbai','Punjab','Haryana','Goa','Uttarakhand','Uttar Pradesh'],
    "Latitude":[28.7041,19.0760,31.1471,29.0588,15.2993,30.0668,26.8467],
    "Longitude":[77.1025,72.8777,75.3412,76.0856,74.1240,79.0193,80.9462],
    "Sales":[150,200,130,120,90,80,170],
    "Units Sold":[12000,18000,11000,9000,7000,6500,15000]
})
chart = fl.Map(location=[15.3494864,73.6770313],
               zoom_start=5,
               zoom_control=True)
colorchart = fl.LinearColormap(colors=["green","red","orange","yellow"],
                              vmin=indian_sales["Sales"].min(),
                              vmax=indian_sales["Sales"].max(),
                              caption="Sales Amount")
for column, row in indian_sales.iterrows():
    fl.CircleMarker(
        location=[row["Latitude"], row["Longitude"]],
        radius=row["Sales"] / 20,
        color=colorchart(row["Sales"]),
        fill=True,
        fill_color=colorchart(row["Sales"]),
        fill_opacity=0.7,
        popup=f"{row['State Name']}: Rs{row['Sales']}M"
        ).add_to(chart)
    colorchart.add_to(chart)
chart
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffba4dc575b99ae2a5e005501d0bb06d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffba4dc575b99ae2a5e005501d0bb06d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffba4dc575b99ae2a5e005501d0bb06d = L.map(
#                 &quot;map_ffba4dc575b99ae2a5e005501d0bb06d&quot;,
#                 {
#                     center: [15.3494864, 73.6770313],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67719295561cdd65561d27fdeef93675 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67719295561cdd65561d27fdeef93675.addTo(map_ffba4dc575b99ae2a5e005501d0bb06d);
#
#
#             var circle_marker_69668fe8a8befa79f0fc4439987ea31f = L.circleMarker(
#                 [28.7041, 77.1025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7c00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff7c00ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffba4dc575b99ae2a5e005501d0bb06d);
#
#
#         var popup_05b60139014bafa30de62abd5b54c059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11a98630cf062aacb4d3ad821cfdd001 = $(`&lt;div id=&quot;html_11a98630cf062aacb4d3ad821cfdd001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Delhi: Rs150M&lt;/div&gt;`)[0];
#                 popup_05b60139014bafa30de62abd5b54c059.setContent(html_11a98630cf062aacb4d3ad821cfdd001);
#
#
#
#         circle_marker_69668fe8a8befa79f0fc4439987ea31f.bindPopup(popup_05b60139014bafa30de62abd5b54c059)
#         ;
#
#
#
#
#     var color_map_fc1f7adafbe6e5116054b99b2642e987 = {};
#
#
#     color_map_fc1f7adafbe6e5116054b99b2642e987.color = d3.scale.threshold()
#               .domain([80.0, 80.24048096192385, 80.4809619238477, 80.72144288577154, 80.96192384769539, 81.20240480961924, 81.44288577154309, 81.68336673346694, 81.92384769539078, 82.16432865731463, 82.40480961923848, 82.64529058116233, 82.88577154308618, 83.12625250501002, 83.36673346693387, 83.60721442885772, 83.84769539078157, 84.0881763527054, 84.32865731462925, 84.5691382765531, 84.80961923847696, 85.0501002004008, 85.29058116232466, 85.53106212424849, 85.77154308617234, 86.0120240480962, 86.25250501002004, 86.49298597194388, 86.73346693386773, 86.97394789579158, 87.21442885771543, 87.45490981963928, 87.69539078156312, 87.93587174348697, 88.17635270541082, 88.41683366733467, 88.65731462925852, 88.89779559118236, 89.13827655310621, 89.37875751503006, 89.61923847695391, 89.85971943887776, 90.1002004008016, 90.34068136272545, 90.5811623246493, 90.82164328657315, 91.062124248497, 91.30260521042084, 91.54308617234469, 91.78356713426854, 92.02404809619239, 92.26452905811624, 92.50501002004007, 92.74549098196393, 92.98597194388778, 93.22645290581163, 93.46693386773546, 93.70741482965931, 93.94789579158316, 94.18837675350701, 94.42885771543087, 94.66933867735472, 94.90981963927855, 95.1503006012024, 95.39078156312625, 95.6312625250501, 95.87174348697394, 96.11222444889779, 96.35270541082164, 96.59318637274549, 96.83366733466934, 97.0741482965932, 97.31462925851703, 97.55511022044088, 97.79559118236473, 98.03607214428858, 98.27655310621242, 98.51703406813627, 98.75751503006012, 98.99799599198397, 99.23847695390782, 99.47895791583167, 99.71943887775551, 99.95991983967936, 100.20040080160321, 100.44088176352706, 100.6813627254509, 100.92184368737475, 101.1623246492986, 101.40280561122245, 101.6432865731463, 101.88376753507015, 102.12424849699399, 102.36472945891784, 102.60521042084169, 102.84569138276552, 103.08617234468937, 103.32665330661322, 103.56713426853707, 103.80761523046093, 104.04809619238478, 104.28857715430861, 104.52905811623246, 104.76953907815631, 105.01002004008016, 105.250501002004, 105.49098196392785, 105.7314629258517, 105.97194388777555, 106.2124248496994, 106.45290581162325, 106.69338677354709, 106.93386773547094, 107.17434869739479, 107.41482965931864, 107.65531062124248, 107.89579158316633, 108.13627254509018, 108.37675350701403, 108.61723446893788, 108.85771543086173, 109.09819639278557, 109.33867735470942, 109.57915831663327, 109.81963927855712, 110.06012024048096, 110.3006012024048, 110.54108216432866, 110.78156312625251, 111.02204408817636, 111.26252505010021, 111.50300601202404, 111.7434869739479, 111.98396793587175, 112.2

# %%
indian_sales = pd.DataFrame({
    "State Name":['Delhi','Mumbai','Punjab','Haryana','Goa','Uttarakhand','Uttar Pradesh'],
    "Latitude":[28.7041,19.0760,31.1471,29.0588,15.2993,30.0668,26.8467],
    "Longitude":[77.1025,72.8777,75.3412,76.0856,74.1240,79.0193,80.9462],
    "Sales":[150,200,130,120,90,80,170],
    "Units Sold":[12000,18000,11000,9000,7000,6500,15000]
})

# %%
chart = fl.Map(location=[15.3494864,73.6770313],
               zoom_start=5,
               zoom_control=True,
              tiles="CartoDB dark_matter")
colorchart = fl.LinearColormap(colors=["green","yellow",'orange','red'],
                              vmin=indian_sales["Sales"].min(),
                              vmax=indian_sales["Sales"].max(),
                              caption="Sales Amount")
for column, row in indian_sales.iterrows():
    fl.CircleMarker(
        location=[row["Latitude"], row["Longitude"]],
        radius=row["Sales"] / 20,
        color=colorchart(row["Sales"]),
        fill=True,
        fill_color=colorchart(row["Sales"]),
        fill_opacity=0.7,
        popup=f"{row['State Name']}: Rs{row['Sales']}M"
        ).add_to(chart)
    colorchart.add_to(chart)
chart
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16c84830485133d31b74c9017bb9c7a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16c84830485133d31b74c9017bb9c7a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16c84830485133d31b74c9017bb9c7a3 = L.map(
#                 &quot;map_16c84830485133d31b74c9017bb9c7a3&quot;,
#                 {
#                     center: [15.3494864, 73.6770313],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d7c701fd1e4c7a67ea0a96d0e70bb89 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_